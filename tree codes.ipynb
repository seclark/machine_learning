# %%
# %pylab inline --no-import-all
from IPython.display import Image
np.random.seed(0)
np.set_printoptions(precision=2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Bad key "grid.alpha" on line 271 in
# /Users/laurennc/.matplotlib/matplotlibrc.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "savefig.bbox" on line 353 in
# /Users/laurennc/.matplotlib/matplotlibrc.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution

# %% [markdown]
# # multidimensional trees

# %%
Image(url='http://entrance.tv/images/collection%20Daniel%20Pavon%20Cuellar%20Art%20Dapacu%20TREES.jpg')
# Out:
# <img src="http://entrance.tv/images/collection%20Daniel%20Pavon%20Cuellar%20Art%20Dapacu%20TREES.jpg"/>

# %% [markdown]
# ###Section 2.5.2: Multidimensional searches and other operations###
#
# First, a quick reminder on binary search trees (BSTs). BSTs are sorted binary trees. The "binary" part means that each node has at most two children, and the "sorted" part means that each node has a value (key) that is larger than all of the keys in all of the nodes that sprout from its left node, and smaller than all of the keys in all of the nodes that sprout from its right node. (The below picture is a simple example.)
#
# Each node is either the "root" of another tree (recursion!) or a "leaf", containing data.
#
# Remember trees! We'll see them again when we get to tree classifiers.

# %%
Image(url='http://upload.wikimedia.org/wikipedia/commons/d/da/Binary_search_tree.svg')
# Out:
# <img src="http://upload.wikimedia.org/wikipedia/commons/d/da/Binary_search_tree.svg"/>

# %% [markdown]
# Now to the **multidimensional** bit.
#
# Multidimensional trees are just what they sound like: indexing structures that can handle multidimensional data. A single tree for a data set (if the data set doesn't change) can be used to speed up lots of machine learning algorithms.
#
# **generalized N-body problem**: any problem involving distances or other similarities between (all or many) pairs (or n-tuples) of points.
#
# The most efficient way to deal with generalized N-Body problems (Section 2.3) is via *multidimensional trees*. The build time is usually $\mathcal{O}(N \log N)$ and the single query time is $\mathcal{O}(\log N)$.
#
# E.g. Nearest-neighbor searches, minimize Euclidean metric:
# <center>$D(x, x_i) = \sqrt{\sum\limits^D_{d=1}(x_d-x_{i,d})^2}$</center>
#
# </br>
# Brute-force way: compute distance between every pair of points. Find the closest. Ha-ha! So easy!
#
# ... But scales as $\mathcal{O}(N^2)$ ... :(

# %% [markdown]
# **Quad-trees and oct-trees:**

# %%
"""
Quad Tree Example
-----------------
Figure 2.3.

This example creates a simple quad-tree partition of a two-dimensional
parameter space, and plots a visualization of the result.
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=12, usetex=False)


# We'll create a QuadTree class which will recursively subdivide the
# space into quadrants
class QuadTree:
    """Simple Quad-tree class"""

    # class initialization function
    def __init__(self, data, mins, maxs, depth=3):
        self.data = np.asarray(data)

        # data should be two-dimensional
        assert self.data.shape[1] == 2

        if mins is None:
            mins = data.min(0)
        if maxs is None:
            maxs = data.max(0)

        self.mins = np.asarray(mins)
        self.maxs = np.asarray(maxs)
        self.sizes = self.maxs - self.mins

        self.children = []

        mids = 0.5 * (self.mins + self.maxs)
        xmin, ymin = self.mins
        xmax, ymax = self.maxs
        xmid, ymid = mids

        if depth > 0:
            # split the data into four quadrants
            data_q1 = data[(data[:, 0] < mids[0])
                           & (data[:, 1] < mids[1])]
            data_q2 = data[(data[:, 0] < mids[0])
                           & (data[:, 1] >= mids[1])]
            data_q3 = data[(data[:, 0] >= mids[0])
                           & (data[:, 1] < mids[1])]
            data_q4 = data[(data[:, 0] >= mids[0])
                           & (data[:, 1] >= mids[1])]

            # recursively build a quad tree on each quadrant which has data
            if data_q1.shape[0] > 0:
                self.children.append(QuadTree(data_q1,
                                              [xmin, ymin], [xmid, ymid],
                                              depth - 1))
            if data_q2.shape[0] > 0:
                self.children.append(QuadTree(data_q2,
                                              [xmin, ymid], [xmid, ymax],
                                              depth - 1))
            if data_q3.shape[0] > 0:
                self.children.append(QuadTree(data_q3,
                                              [xmid, ymin], [xmax, ymid],
                                              depth - 1))
            if data_q4.shape[0] > 0:
                self.children.append(QuadTree(data_q4,
                                              [xmid, ymid], [xmax, ymax],
                                              depth - 1))

    def draw_rectangle(self, ax, depth):
        """Recursively plot a visualization of the quad tree region"""
        if depth is None or depth == 0:
            rect = plt.Rectangle(self.mins, *self.sizes, zorder=2,
                                 ec='#000000', fc='none')
            ax.add_patch(rect)
        if depth is None or depth > 0:
            for child in self.children:
                child.draw_rectangle(ax, depth - 1)


def draw_grid(ax, xlim, ylim, Nx, Ny, **kwargs):
    """ draw a background grid for the quad tree"""
    for x in np.linspace(xlim[0], xlim[1], Nx):
        ax.plot([x, x], ylim, **kwargs)
    for y in np.linspace(ylim[0], ylim[1], Ny):
        ax.plot(xlim, [y, y], **kwargs)


#------------------------------------------------------------
# Create a set of structured random points in two dimensions
np.random.seed(0)

X = np.random.random((30, 2)) * 2 - 1
X[:, 1] *= 0.1
X[:, 1] += X[:, 0] ** 2

#------------------------------------------------------------
# Use our Quad Tree class to recursively divide the space
mins = (-1.1, -0.1)
maxs = (1.1, 1.1)
QT = QuadTree(X, mins, maxs, depth=3)

#------------------------------------------------------------
# Plot four different levels of the quad tree
fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(wspace=0.1, hspace=0.15,
                    left=0.1, right=0.9,
                    bottom=0.05, top=0.9)

for level in range(1, 5):
    ax = fig.add_subplot(2, 2, level, xticks=[], yticks=[])
    ax.scatter(X[:, 0], X[:, 1], s=40)
    QT.draw_rectangle(ax, depth=level - 1)

    Nlines = 1 + 2 ** (level - 1)
    draw_grid(ax, (mins[0], maxs[0]), (mins[1], maxs[1]),
              Nlines, Nlines, linewidth=1,
              color='#CCCCCC', zorder=0)

    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-0.15, 1.15)
    ax.set_title('level %i' % level)

# suptitle() adds a title to the entire figure
fig.suptitle('Quad-tree Example')
plt.show()

# %% [markdown]
# spatial domain is recursively divided in equal sized sub-domains (two dimensions: quad-tree, three dimensions: oct-tree) until the number of data points remaining in a 'leaf' drops below a threshold value (inherently adaptive). Very commonly used in simulation codes.
# If the minumum distance to a tree-node is larger than the currently best candidate, all members of that node can be discarded.

# %% [markdown]
# **kd-trees (k-dimensional trees)**

# %%
"""
KD Tree Example
---------------
Figure 2.4.

This example creates a simple KD-tree partition of a two-dimensional
parameter space, and plots a visualization of the result.
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=12, usetex=False)


# We'll create a KDTree class which will recursively subdivide the
# space into rectangular regions.  Note that this is just an example
# and shouldn't be used for real computation; instead use the optimized
# code in scipy.spatial.cKDTree or sklearn.neighbors.BallTree
class KDTree:
    """Simple KD tree class"""

    # class initialization function
    def __init__(self, data, mins, maxs):
        self.data = np.asarray(data)

        # data should be two-dimensional
        assert self.data.shape[1] == 2

        if mins is None:
            mins = data.min(0)
        if maxs is None:
            maxs = data.max(0)

        self.mins = np.asarray(mins)
        self.maxs = np.asarray(maxs)
        self.sizes = self.maxs - self.mins

        self.child1 = None
        self.child2 = None

        if len(data) > 1:
            # sort on the dimension with the largest spread
            largest_dim = np.argmax(self.sizes)
            i_sort = np.argsort(self.data[:, largest_dim])
            self.data[:] = self.data[i_sort, :]

            # find split point
            N = self.data.shape[0]
            split_point = 0.5 * (self.data[N / 2, largest_dim]
                                 + self.data[N / 2 - 1, largest_dim])

            # create subnodes
            mins1 = self.mins.copy()
            mins1[largest_dim] = split_point
            maxs2 = self.maxs.copy()
            maxs2[largest_dim] = split_point

            # Recursively build a KD-tree on each sub-node
            self.child1 = KDTree(self.data[N / 2:], mins1, self.maxs)
            self.child2 = KDTree(self.data[:N / 2], self.mins, maxs2)

    def draw_rectangle(self, ax, depth=None):
        """Recursively plot a visualization of the KD tree region"""
        if depth == 0:
            rect = plt.Rectangle(self.mins, *self.sizes, ec='k', fc='none')
            ax.add_patch(rect)

        if self.child1 is not None:
            if depth is None:
                self.child1.draw_rectangle(ax)
                self.child2.draw_rectangle(ax)
            elif depth > 0:
                self.child1.draw_rectangle(ax, depth - 1)
                self.child2.draw_rectangle(ax, depth - 1)


#------------------------------------------------------------
# Create a set of structured random points in two dimensions
np.random.seed(0)

X = np.random.random((30, 2)) * 2 - 1
X[:, 1] *= 0.1
X[:, 1] += X[:, 0] ** 2

#------------------------------------------------------------
# Use our KD Tree class to recursively divide the space
KDT = KDTree(X, [-1.1, -0.1], [1.1, 1.1])

#------------------------------------------------------------
# Plot four different levels of the KD tree
fig = plt.figure(figsize=(10, 10))
fig.subplots_adjust(wspace=0.1, hspace=0.15,
                    left=0.1, right=0.9,
                    bottom=0.05, top=0.9)

for level in range(1, 5):
    ax = fig.add_subplot(2, 2, level, xticks=[], yticks=[])
    ax.scatter(X[:, 0], X[:, 1], s=30)
    KDT.draw_rectangle(ax, depth=level - 1)

    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-0.15, 1.15)
    ax.set_title('level %i' % level)

# suptitle() adds a title to the entire figure
fig.suptitle('$k$d-tree Example')
plt.show()

# %% [markdown]
# The quad tree can be easily extended to a higher number of dimensions D but with $2^D$ children per node this becomes quickly unfeasible. Kd-trees only use 2 children per node (binary tree) but iterate between dimensions at each recursion level. Included in SciPy.
# Still not suited for very high number of dimensions D, since one must go D levels deep to split each dimension once (e.g. D=100 -> $2^{100} \approx 10^{30}$)

# %% [markdown]
# **Ball-trees**

# %%
"""
Ball Tree Example
-----------------
Figure 2.5.

This example creates a simple Ball tree partition of a two-dimensional
parameter space, and plots a visualization of the result.
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=12, usetex=False)


# We'll create a BallTree class which will recursively subdivide the
# space into circular regions.  Note that this is just an example and
# shouldn't be used for real computation; instead use the optimized
# code in scipy.spatial.cKDTree or sklearn.neighbors.BallTree
class BallTree:
    """Simple Ball tree class"""

    # class initialization function
    def __init__(self, data):
        self.data = np.asarray(data)

        # data should be two-dimensional
        assert self.data.shape[1] == 2

        self.loc = data.mean(0)
        self.radius = np.sqrt(np.max(np.sum((self.data - self.loc) ** 2, 1)))

        self.child1 = None
        self.child2 = None

        if len(self.data) > 1:
            # sort on the dimension with the largest spread
            largest_dim = np.argmax(self.data.max(0) - self.data.min(0))
            i_sort = np.argsort(self.data[:, largest_dim])
            self.data[:] = self.data[i_sort, :]

            # find split point
            N = self.data.shape[0]
            split_point = 0.5 * (self.data[N / 2, largest_dim]
                                 + self.data[N / 2 - 1, largest_dim])

            # recursively create subnodes
            self.child1 = BallTree(self.data[N / 2:])
            self.child2 = BallTree(self.data[:N / 2])

    def draw_circle(self, ax, depth=None):
        """Recursively plot a visualization of the Ball tree region"""
        if depth is None or depth == 0:
            circ = Circle(self.loc, self.radius, ec='k', fc='none')
            ax.add_patch(circ)

        if self.child1 is not None:
            if depth is None:
                self.child1.draw_circle(ax)
                self.child2.draw_circle(ax)
            elif depth > 0:
                self.child1.draw_circle(ax, depth - 1)
                self.child2.draw_circle(ax, depth - 1)


#------------------------------------------------------------
# Create a set of structured random points in two dimensions
np.random.seed(0)
X = np.random.random((30, 2)) * 2 - 1
X[:, 1] *= 0.1
X[:, 1] += X[:, 0] ** 2

#------------------------------------------------------------
# Use our Ball Tree class to recursively divide the space
BT = BallTree(X)

#------------------------------------------------------------
# Plot four different levels of the Ball tree
fig = plt.figure(figsize=(10, 10))
fig.subplots_adjust(wspace=0.1, hspace=0.15,
                    left=0.1, right=0.9,
                    bottom=0.05, top=0.9)

for level in range(1, 5):
    ax = fig.add_subplot(2, 2, level, xticks=[], yticks=[])
    ax.scatter(X[:, 0], X[:, 1], s=30)
    BT.draw_circle(ax, depth=level - 1)

    ax.set_xlim(-1.35, 1.35)
    ax.set_ylim(-1.0, 1.7)
    ax.set_title('level %i' % level)

# suptitle() adds a title to the entire figure
fig.suptitle('Ball-tree Example')
plt.show()

# %% [markdown]
# Instead of using rectilinear nodes in D dimensions, ball-tree construction builds hyperspherical nodes. Each node is given by a centroid and $c_i$ and a radius $r_i$, such that the Distance $D(y,c_i) \leq r_i$ for every point $y$ contained in the node. For every point x outside the node:
# <center>
# $[D(x,c_i)-r_i] \leq D(x,y) \leq [D(x,c_i) + r_i]$
# </center>
# Included in the Scikit-learn package.

# %% [markdown]
# ### -----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Application: N-body Simulations

# %% [markdown]
# The properties of the dark matter fluid in cosmological simulations are usually solved for by sampling the phase-space density by a finite number of N tracer particles.  Their motion is dictated by gravity and the calculation of the force on each particle can be done in a number of different ways.

# %% [markdown]
# ### Direct Calcuation

# %% [markdown]
# $\Phi = - \mathrm{G} \sum\limits_j \frac{m_j}{(\lvert r - r_j\rvert\ + \epsilon^2)^{1/2}}$

# %% [markdown]
# Disadvantage: $\mathcal{O}(N^2)$ though great progress with GPUs

# %% [markdown]
# ### Trees (see Barnes & Hut 1986)

# %% [markdown]
# Here, the gravity is calculating by traversing a tree that encompasses all of the DM particles. The distance particles exert a much smaller force than those nearby so calculating their gravity together, when reasonable, doesn't change the final answer much but speeds up the process significantly.

# %% [markdown]
# Starting at the "root" node, the code looks at each leaf and decides if the gravity can be approximated by the leaf or split into its nodes.  This process is continued until the entire tree is evaluated. Whether the leaf is split into nodes is decided by the "opening criteria"

# %%
Image(filename='barnes_tree.png')

# %% [markdown]
# In Barnes and Hut, the opening criteria is determined in the following way.  Let $l$ be the length of the cell being processed and $D$ be the distance from the cell's center of mass to point p. If $l/D < \theta$, then include this interaction. If not, split the cell into its nodes and continue.  Here, $\theta$ can be set to arbitrary accuracy, which when small enough reverts to a direct summation.

# %% [markdown]
# Advantage:     It's easy to control the accuracy of the simulation and it's much faster than a direct calculation.
#
# Disadvantage:  You are adding inaccuracies by grouping particles

# %% [markdown]
# ### Particle-Mesh (PM)

# %% [markdown]
# The Particle-Mesh method treats the force as a field quantity where the potential and force are then interpolated over an array instead of point-wise.

# %% [markdown]
# #### General Method:

# %% [markdown]
#     1) Assign N-body particles to an underlying mesh to calculate a mass density

# %%
Image(filename='pm_smoothing.png')

# %% [markdown]
#     2) Transform density field to Fourier space so the force can be calculated using finite difference schemes.
#     3) Reassign force to particles and update their positions.

# %% [markdown]
# Advantage:    $\mathcal{O}(N + N_g \log N_g)$ ; N = grid points, N$_g$ = particles
#
# Disadvantage: dynamical range/number of grid cells limited by memory; Solution: Adaptive Mesh Refinement

# %% [markdown]
# ### TreePM

# %% [markdown]
# This is a hybrid between the two above methods.  The force calculation is split into two parts: long and short.

# %% [markdown]
# For the long range, the force is computed using the PM methods.  The smoothing issues aren't as important at long distances where the exact location of the particle is less important.

# %% [markdown]
# For the short range, the force is computed using the tree methods. Here, you benefit from the arbitrary dynamical resolution that comes from building the tree instead of assigning particles to grid points. You also maintain control over the softening length, allowing you to control the accuracy.

# %%
Image(filename='gadget_accuracy.png')

# %% [markdown]
# ### What do different codes use?

# %% [markdown]
# AMR codes like Enzo and FLASH use PM methods. They're already calculating the gas properties on the grid so incorporating the gravity makes sense.

# %% [markdown]
# GADGET in all of its forms uses a modified TreePM code as shown above.

# %% [markdown]
# In general, the results agree but the different methods do have different implications.  The PM codes are limited to resolving things that are larger than the grid size so they consistently under-predict lower mass halos.

# %%
Image(filename='code_compare.png')

# %% [markdown]
# "To reach reasonable good agreement, relatively conservative criteria for the adaptive grid refinement are needed.  Choosing a grid resolution twice as high as the mean inter-particle distance of the DM particles is recommended, to improve the small scale accuracy of the gravity calculation."
